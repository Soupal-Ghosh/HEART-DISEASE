# %%
print("Group name= Me ; member = Soupal Ghosh")
print("The iddea is to create a monitoring system where specifics would be targetted later through backend using opns on a website...")
print("with the little knowledge i have i will try to reach to the closest clone of the same")
print("thank you for bearing with me !! \n\n\n\n")
# Out:
# Group name= Me ; member = Soupal Ghosh
# The iddea is to create a monitoring system where specifics would be targetted later through backend using opns on a website...
# with the little knowledge i have i will try to reach to the closest clone of the same
# thank you for bearing with me !!

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# loading the csv data to a Pandas DataFrame
hdf = pd.read_csv('/content/heart_disease_data.csv')

# %%
hdf.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
hdf.shape
# Out:
# (303, 14)

# %%
hdf.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
X = hdf.drop(columns='target', axis=1)
Y =hdf['target']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (303, 13) (242, 13) (61, 13)

# %%
model = LogisticRegression()
model.fit(X_train, Y_train)
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data : ', training_data_accuracy)
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Training data :  0.8512396694214877
# Accuracy on Test data :  0.819672131147541
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
age=int(input("enter age"))
sex=int(input("1 for male 0 for female"))
cp=int(input("enter cp"))
trestbps=int(input("enter trestbps"))
chol=int(input("enter chol"))
fbs=int(input("enter fbs"))
restecg=int(input("enter restecg"))
thalach=int(input("enter thalach"))
exang=int(input("enter exang"))
oldpeak=float(input("enter oldpeak"))
slope=int(input("enter slope"))
ca=int(input("enter ca"))
thal=int(input("enter thal"))

input_data = (age,sex,cp,trestbps,chol,fbs,restecg,thalach,exang,oldpeak,slope,ca,thal)

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="sklearn")
prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
  print('The Person does not have a Heart Disease')
else:
  print('The Person has Heart Disease')
# Out:
# enter age67
# 1 for male 0 for female1
# enter cp0
# enter trestbps160
# enter chol286
# enter fbs0
# enter restecg0
# enter thalach108
# enter exang1
# enter oldpeak1.5
# enter slope1
# enter ca3
# enter thal2
# [0]
# The Person does not have a Heart Disease
